# %% [markdown]
# # Night Image Enhancement
# ### Imports
# - We can skip the next cell if neural_de was installed from pip install.

# %%
import sys
sys.path.append("..")
import time

# %%
from neural_de.transformations.night_image_enhancer import NightImageEnhancer
import numpy as np
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's load and display our sample night image :

# %%
start=time.time()
image_path = Path('../examples/images/night.jpg')
image = cv2.imread(str(image_path))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title(image.shape)
# Out:
# Text(0.5, 1.0, '(427, 640, 3)')

# %% [markdown]
# ### Usage

# %%
purifier = NightImageEnhancer()
import time
t1 = time.time()
print(t1)
purified = purifier.transform([image])
print(time.time()-t1)
# Out:
# [03-19 17:06:45] {C:\SAUVEGARDES_FIN_CONFIANCE\FONDATION\Support_composants\NeuralDE\examples\..\neural_de\utils\twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# [03-19 17:07:35] {C:\SAUVEGARDES_FIN_CONFIANCE\FONDATION\Support_composants\NeuralDE\examples\..\neural_de\transformations\night_image_enhancer.py:57} INFO - Model https://tfhub.dev/sayakpaul/maxim_s-2_enhancement_fivek/1 loaded
# INFO:neural_de_logger:Model https://tfhub.dev/sayakpaul/maxim_s-2_enhancement_fivek/1 loaded
# 1742400455.0378497
# [03-19 17:07:35] {C:\SAUVEGARDES_FIN_CONFIANCE\FONDATION\Support_composants\NeuralDE\examples\..\neural_de\transformations\night_image_enhancer.py:114} INFO - New image shape detected, readying model for size (448, 640)
# INFO:neural_de_logger:New image shape detected, readying model for size (448, 640)
# [03-19 17:07:45] {C:\SAUVEGARDES_FIN_CONFIANCE\FONDATION\Support_composants\NeuralDE\examples\..\neural_de\transformations\night_image_enhancer.py:117} INFO - Model ready for image size (448, 640)
# INFO:neural_de_logger:Model ready for image size (448, 640)
# 1/1 [==============================] - 31s 31s/step
# 41.58003830909729

# %%
plt.imshow(purified[0])
end=time.time()
print("temps final : ",end-start)
# Out:
# temps final :  92.91288661956787
